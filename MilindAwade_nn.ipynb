# %% [markdown]
# ### Importing Skin Cancer Data

# %% [markdown]
# ##### Importing all the important libraries

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import os

# %%
##Mapping the Data
train_dir = 'Train'
test_dir = 'Test'

# %% [markdown]
# # Creating Dataset

# %%
batch_size = 32
img_size = (180, 180)

train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 1795 images belonging to 9 classes.
# Found 444 images belonging to 9 classes.
# Found 118 images belonging to 9 classes.

# %% [markdown]
# # Visualize the data

# %%
#Fetching class details
class_names = list(train_generator.class_indices.keys())
class_indices = train_generator.class_indices

#Initialize a dictionary to store 1 image per class
images_per_class = {class_name: None for class_name in class_names}

#Iterate until we have 1 image for each class
for images, labels in train_generator:
    for img, label in zip(images, labels):
        class_index = tf.argmax(label).numpy()
        class_name = class_names[class_index]
        if images_per_class[class_name] is None:
            images_per_class[class_name] = img
        #output
        print(f"Processed image for class: {class_name}")
    #Check if we have found one image for each class
    if all(value is not None for value in images_per_class.values()):
        break

#Plot the images
plt.figure(figsize=(12, 12))
for i, (class_name, img) in enumerate(images_per_class.items()):
    plt.subplot(3, 3, i + 1)
    plt.imshow(img)
    plt.title(class_name)
    plt.axis('off')
plt.show()
# Out:
# Processed image for class: basal cell carcinoma
# Processed image for class: pigmented benign keratosis
# Processed image for class: melanoma
# Processed image for class: dermatofibroma
# Processed image for class: pigmented benign keratosis
# Processed image for class: vascular lesion
# Processed image for class: basal cell carcinoma
# Processed image for class: basal cell carcinoma
# Processed image for class: nevus
# Processed image for class: pigmented benign keratosis
# Processed image for class: actinic keratosis
# Processed image for class: actinic keratosis
# Processed image for class: pigmented benign keratosis
# Processed image for class: basal cell carcinoma
# Processed image for class: melanoma
# Processed image for class: pigmented benign keratosis
# Processed image for class: vascular lesion
# Processed image for class: basal cell carcinoma
# Processed image for class: squamous cell carcinoma
# Processed image for class: nevus
# Processed image for class: pigmented benign keratosis
# Processed image for class: actinic keratosis
# Processed image for class: nevus
# Processed image for class: pigmented benign keratosis
# Processed image for class: pigmented benign keratosis
# Processed image for class: pigmented benign keratosis
# Processed image for class: squamous cell carcinoma
# Processed image for class: pigmented benign keratosis
# Processed image for class: seborrheic keratosis
# Processed image for class: squamous cell carcinoma
# Processed image for class: squamous cell carcinoma
# Processed image for class: nevus

# %%
#Model Building & Training
#Initial Model

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(180, 180, 3)),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(9, activation='softmax')
])
# Out:
# C:\Users\Milind\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# # Compile the Model

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Train the model

# %%
history = model.fit(
    train_generator,
    epochs=20,
    validation_data=validation_generator
)
# Out:
# C:\Users\Milind\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 97s 2s/step - accuracy: 0.1947 - loss: 2.6353 - val_accuracy: 0.3739 - val_loss: 1.8843
# Epoch 2/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 28s 493ms/step - accuracy: 0.3653 - loss: 1.7615 - val_accuracy: 0.3536 - val_loss: 1.8347
# Epoch 3/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 29s 507ms/step - accuracy: 0.4634 - loss: 1.5615 - val_accuracy: 0.4482 - val_loss: 1.7321
# Epoch 4/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 28s 496ms/step - accuracy: 0.4930 - loss: 1.4641 - val_accuracy: 0.4279 - val_loss: 1.9143
# Epoch 5/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 29s 512ms/step - accuracy: 0.5007 - loss: 1.4328 - val_accuracy: 0.4302 - val_loss: 1.9265
# Epoch 6/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 29s 502ms/step - accuracy: 0.5248 - loss: 1.3797 - val_accuracy: 0.4640 - val_loss: 1.7560
# Epoch 7/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 29s 510ms/step - accuracy: 0.5509 - loss: 1.3558 - val_accuracy: 0.4730 - val_loss: 1.8259
# Epoch 8/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 29s 508ms/step - accuracy: 0.5785 - loss: 1.2166 - val_accuracy: 0.3986 - val_loss: 1.8253
# Epoch 9/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 29s 500ms/step - accuracy: 0.5485 - loss: 1.2608 - val_accuracy: 0.4707 - val_loss: 1.8613
# Epoch 10/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 29s 506ms/step - accuracy: 0.6136 - loss: 1.1290 - val_accuracy: 0.4437 - val_loss: 1.8419
# Epoch 11/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 29s 505ms/step - accuracy: 0.6143 - loss: 1.0761 - val_accuracy: 0.4437 - val_loss: 1.9769
# Epoch 12/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 29s 503ms/step - accuracy: 0.6333 - loss: 0.9840 - val_accuracy: 0.4459 - val_loss: 1.9747
# Epoch 13/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 29s 501ms/step - accuracy: 0.6667 - loss: 0.9472 - val_accuracy: 0.4640 - val_loss: 2.0079
# Epoch 14/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 30s 526ms/step - accuracy: 0.6802 - loss: 0.8865 - val_accuracy: 0.5023 - val_loss: 1.8357
# Epoch 15/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 31s 538ms/step - accuracy: 0.6783 - loss: 0.8987 - val_accuracy: 0.4730 - val_loss: 2.1576
# Epoch 16/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 30s 521ms/step - accuracy: 0.7272 - loss: 0.7770 - val_accuracy: 0.4572 - val_loss: 2.7319
# Epoch 17/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 30s 518ms/step - accuracy: 0.7674 - loss: 0.6815 - val_accuracy: 0.4482 - val_loss: 2.2258
# Epoch 18/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 30s 523ms/step - accuracy: 0.7194 - loss: 0.8207 - val_accuracy: 0.4482 - val_loss: 2.7308
# Epoch 19/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 30s 529ms/step - accuracy: 0.7862 - loss: 0.5844 - val_accuracy: 0.4640 - val_loss: 2.6310
# Epoch 20/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 31s 536ms/step - accuracy: 0.8090 - loss: 0.5132 - val_accuracy: 0.4752 - val_loss: 2.8281

# %% [markdown]
# # Visualize the Training result

# %%
#Analyze the Model Fit

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

#Plotting for Training and Validation Accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

#Plotting for Training and Validation Loss
plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ##### Class Distribution in Training Dataset

# %%
import numpy as np
class_counts = {class_name: 0 for class_name in class_names}
for _, labels in train_generator:
    labels = np.argmax(labels, axis=1)
    for label in labels:
        class_counts[class_names[label]] += 1
    if sum(class_counts.values()) >= train_generator.samples:
        break

#Distribution
print("Class distribution in the training dataset:")
for class_name, count in class_counts.items():
    print(f"{class_name}: {count}")

least_samples_class = min(class_counts, key=class_counts.get)
most_samples_class = max(class_counts, key=class_counts.get)

#Display details
print(f"\nClass with the least number of samples: {least_samples_class}")
print(f"Class that dominates the data: {most_samples_class}")
# Out:
# Class distribution in the training dataset:
# actinic keratosis: 96
# basal cell carcinoma: 299
# dermatofibroma: 75
# melanoma: 353
# nevus: 284
# pigmented benign keratosis: 367
# seborrheic keratosis: 62
# squamous cell carcinoma: 147
# vascular lesion: 112
#
# Class with the least number of samples: seborrheic keratosis
# Class that dominates the data: pigmented benign keratosis

# %% [markdown]
# ##### Initial train count

# %%
import os

#Function to count initial images
def count_initial_images(dir_path, class_names):
    class_counts = {}
    for class_name in class_names:
        class_dir = os.path.join(dir_path, class_name)
        if os.path.exists(class_dir):
            class_counts[class_name] = len(os.listdir(class_dir))
        else:
            class_counts[class_name] = 0
    return class_counts


#Count initial images for all in train directory
initial_train_counts = count_initial_images(train_dir, class_names)
print("Initial train counts:", initial_train_counts)
# Out:
# Initial train counts: {'actinic keratosis': 114, 'basal cell carcinoma': 376, 'dermatofibroma': 95, 'melanoma': 438, 'nevus': 357, 'pigmented benign keratosis': 462, 'seborrheic keratosis': 77, 'squamous cell carcinoma': 181, 'vascular lesion': 139}

# %% [markdown]
# ##### Additional samples needed

# %%
#Desired number of samples per class
required_samples_per_class = 1000

#Calculate additional samples needed for each class
additional_samples_needed = {
    class_name: max(0, required_samples_per_class - count)
    for class_name, count in initial_train_counts.items()
}
print("Additional samples needed:", additional_samples_needed)
# Out:
# Additional samples needed: {'actinic keratosis': 886, 'basal cell carcinoma': 624, 'dermatofibroma': 905, 'melanoma': 562, 'nevus': 643, 'pigmented benign keratosis': 538, 'seborrheic keratosis': 923, 'squamous cell carcinoma': 819, 'vascular lesion': 861}

# %%
# Installing Augmentor class
# !pip install Augmentor
# Out:
# Requirement already satisfied: Augmentor in c:\users\milind\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.2.12)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\milind\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Augmentor) (11.1.0)
# Requirement already satisfied: tqdm>=4.9.0 in c:\users\milind\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Augmentor) (4.67.1)
# Requirement already satisfied: numpy>=1.11.0 in c:\users\milind\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Augmentor) (2.0.2)
# Requirement already satisfied: colorama in c:\users\milind\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>=4.9.0->Augmentor) (0.4.6)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\Milind\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# #### Rectifyin the class imbalance with Data augmentation

# %%
import Augmentor

# Function to apply augmentation proportionally
def apply_augmentation_proportional(dir_path, num_samples):
    p = Augmentor.Pipeline(dir_path)
    p.zoom(probability=0.5, min_factor=1.1, max_factor=1.2)
    p.sample(num_samples)  # Number of samples to generate

# Apply augmentation to all classes in train directory
for class_name, num_samples in additional_samples_needed.items():
    train_class_dir = os.path.join(train_dir, class_name)
    if os.path.exists(train_class_dir) and num_samples > 0:
        apply_augmentation_proportional(train_class_dir, num_samples)
    else:
        print(f"Warning: Train class directory {train_class_dir} does not exist or no additional samples needed.")
# Out:
# Initialised with 114 image(s) found.
# Output directory set to Train\actinic keratosis\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x1C1169DEDD0>: 100%|██████████| 886/886 [00:02<00:00, 402.01 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to Train\basal cell carcinoma\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x1C116863310>: 100%|██████████| 624/624 [00:01<00:00, 365.88 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to Train\dermatofibroma\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x1C1168970D0>: 100%|██████████| 905/905 [00:02<00:00, 415.57 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to Train\melanoma\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x1C1166BFCD0>: 100%|██████████| 562/562 [00:03<00:00, 163.27 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to Train\nevus\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=919x802 at 0x1C0F0EF7710>: 100%|██████████| 643/643 [00:03<00:00, 174.88 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to Train\pigmented benign keratosis\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x1C1166B3AD0>: 100%|██████████| 538/538 [00:01<00:00, 421.73 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to Train\seborrheic keratosis\output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x1C116311310>: 100%|██████████| 923/923 [00:03<00:00, 296.87 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to Train\squamous cell carcinoma\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x1C11679B0D0>: 100%|██████████| 819/819 [00:01<00:00, 440.50 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to Train\vascular lesion\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x1C116553750>: 100%|██████████| 861/861 [00:02<00:00, 425.20 Samples/s]

# %% [markdown]
# ##### Applying augmentation strategy

# %%
#(without additional augmentation since Augmentor has been used)
#Ensure to have a validation split
train_datagen_augmented = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2  
)

test_datagen = ImageDataGenerator(rescale=1./255)

#Create generators for augmented data -  This should now include augmented images
train_generator_augmented = train_datagen_augmented.flow_from_directory(
    train_dir, 
    target_size=(180, 180),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

#This should now include augmented images
validation_generator_augmented = train_datagen_augmented.flow_from_directory(
    train_dir,  
    target_size=(180, 180),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
 #Test directory, typically without augmentation
test_generator = test_datagen.flow_from_directory(
    test_dir, 
    target_size=(180, 180),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 7200 images belonging to 9 classes.
# Found 1800 images belonging to 9 classes.
# Found 118 images belonging to 9 classes.

# %% [markdown]
# #### Model Building & training on the rectified class imbalance data

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

#Define the model
model = Sequential([
    Conv2D(64, (3, 3), activation='relu', input_shape=(180, 180, 3)),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(256, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(512, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(1024, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(9, activation='softmax')
])

#Compile the model
optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

#Train the model
history = model.fit(
    train_generator_augmented,
    epochs=30,
    validation_data=validation_generator_augmented
)
# Out:
# Epoch 1/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 358s 2s/step - accuracy: 0.3506 - loss: 2.2556 - val_accuracy: 0.1111 - val_loss: 4.2527
# Epoch 2/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 335s 1s/step - accuracy: 0.5580 - loss: 1.4133 - val_accuracy: 0.3467 - val_loss: 2.1754
# Epoch 3/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 335s 1s/step - accuracy: 0.6396 - loss: 1.1179 - val_accuracy: 0.5789 - val_loss: 1.2512
# Epoch 4/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 338s 2s/step - accuracy: 0.7207 - loss: 0.8641 - val_accuracy: 0.6694 - val_loss: 0.9570
# Epoch 5/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 344s 2s/step - accuracy: 0.7498 - loss: 0.7553 - val_accuracy: 0.6394 - val_loss: 1.0832
# Epoch 6/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 336s 1s/step - accuracy: 0.7714 - loss: 0.6875 - val_accuracy: 0.6833 - val_loss: 1.0292
# Epoch 7/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 334s 1s/step - accuracy: 0.8345 - loss: 0.5071 - val_accuracy: 0.7450 - val_loss: 0.7971
# Epoch 8/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 336s 1s/step - accuracy: 0.8421 - loss: 0.4622 - val_accuracy: 0.7550 - val_loss: 0.7746
# Epoch 9/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 337s 1s/step - accuracy: 0.8704 - loss: 0.3769 - val_accuracy: 0.7656 - val_loss: 0.8327
# Epoch 10/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 338s 1s/step - accuracy: 0.8825 - loss: 0.3373 - val_accuracy: 0.5661 - val_loss: 1.8894
# Epoch 11/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 338s 2s/step - accuracy: 0.9059 - loss: 0.2747 - val_accuracy: 0.7528 - val_loss: 0.8383
# Epoch 12/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 342s 2s/step - accuracy: 0.9080 - loss: 0.2730 - val_accuracy: 0.7794 - val_loss: 0.7527
# Epoch 13/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 378s 2s/step - accuracy: 0.9081 - loss: 0.2621 - val_accuracy: 0.7939 - val_loss: 0.5718
# Epoch 14/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 317s 1s/step - accuracy: 0.9063 - loss: 0.2619 - val_accuracy: 0.7233 - val_loss: 1.0296
# Epoch 15/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 297s 1s/step - accuracy: 0.9188 - loss: 0.2408 - val_accuracy: 0.7689 - val_loss: 0.8397
# Epoch 16/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 299s 1s/step - accuracy: 0.9251 - loss: 0.2168 - val_accuracy: 0.7572 - val_loss: 0.8744
# Epoch 17/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 352s 2s/step - accuracy: 0.9308 - loss: 0.2045 - val_accuracy: 0.7350 - val_loss: 0.8774
# Epoch 18/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 336s 1s/step - accuracy: 0.9229 - loss: 0.2114 - val_accuracy: 0.7922 - val_loss: 0.6940
# Epoch 19/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 338s 2s/step - accuracy: 0.9249 - loss: 0.2081 - val_accuracy: 0.7522 - val_loss: 0.9622
# Epoch 20/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 337s 1s/step - accuracy: 0.9338 - loss: 0.1834 - val_accuracy: 0.7800 - val_loss: 0.6978
# Epoch 21/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 319s 1s/step - accuracy: 0.9403 - loss: 0.1728 - val_accuracy: 0.7761 - val_loss: 0.7410
# Epoch 22/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 319s 1s/step - accuracy: 0.9291 - loss: 0.1838 - val_accuracy: 0.7428 - val_loss: 0.8935
# Epoch 23/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 312s 1s/step - accuracy: 0.9341 - loss: 0.1641 - val_accuracy: 0.8044 - val_loss: 0.6558
# Epoch 24/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 307s 1s/step - accuracy: 0.9437 - loss: 0.1524 - val_accuracy: 0.7600 - val_loss: 0.8107
# Epoch 25/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 315s 1s/step - accuracy: 0.9542 - loss: 0.1352 - val_accuracy: 0.7861 - val_loss: 0.9018
# Epoch 26/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 333s 1s/step - accuracy: 0.9410 - loss: 0.1587 - val_accuracy: 0.7067 - val_loss: 1.1844
# Epoch 27/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 300s 1s/step - accuracy: 0.9406 - loss: 0.1624 - val_accuracy: 0.7500 - val_loss: 0.8891
# Epoch 28/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 307s 1s/step - accuracy: 0.9264 - loss: 0.2013 - val_accuracy: 0.6528 - val_loss: 1.5449
# Epoch 29/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 335s 1s/step - accuracy: 0.9443 - loss: 0.1458 - val_accuracy: 0.7867 - val_loss: 0.7479
# Epoch 30/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 310s 1s/step - accuracy: 0.9380 - loss: 0.1652 - val_accuracy: 0.8011 - val_loss: 0.7273

# %%
#Accuracy and Loss History Values
acc_aug = history.history['accuracy']
val_acc_aug = history.history['val_accuracy']
loss_aug = history.history['loss']
val_loss_aug = history.history['val_loss']

#Plot for Training and Validation Accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(acc_aug, label='Training Accuracy')
plt.plot(val_acc_aug, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy (Augmented)')

#Plot for Training and Validation Loss
plt.subplot(1, 2, 2)
plt.plot(loss_aug, label='Training Loss')
plt.plot(val_loss_aug, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss (Augmented)')
plt.show()

# %% [markdown]
# #**Observations**
#
# **Training Accuracy:** Initially low, it steadily improved, accuracy peaking at 25 epochs with 95.42%, however at with 30th epoch achieving approximately 93.80%.
#
# **Validation Accuracy:** Showed improvement, with a high of about 80.11% at the end.
#
# ----
#
# #**Recommendations:**
#
# **Early Stopping:** Use early stopping to prevent overtraining by stopping when validation performance no longer improves.
#
# **Learning Rate Adjustment:** If there are signs of instability, consider lowering the learning rate.
#
# **Data Augmentation:** Increase the variety of data augmentation techniques to enhance model generalization.
#
# **Regularization Techniques:**
#
#  **1. Dropout Layers:** Fine-tune dropout rates to combat overfitting.
#
#  **2. L2 Regularization:** Implement L2 regularization on both convolutional and dense layers.
